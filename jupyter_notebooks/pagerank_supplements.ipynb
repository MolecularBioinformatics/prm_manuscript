# %%
import warnings
warnings.filterwarnings('ignore')

import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np
import plotting as plot
import itertools

import pyreporter as pr

import recon
model = recon.recon.Recon()
util = recon.utilities.Utilities()

# sns.set_style('white')
sns.set_style('ticks')

# %%
model.gpr
# Out:
# {'13DAMPPOX': '8639.1 or 26.1 or 314.2 or 314.1',
#  '24_25VITD2Hm': '1591.1',
#  '24_25VITD3Hm': '1591.1',
#  '25VITD2Hm': '1594.1',
#  '25VITD3Hm': '1594.1',
#  '2AMACHYD': '10993.1',
#  '2AMACSULT': '6818.1',
#  '2AMADPTm': '89874.1',
#  '2HBO': '92483.1 or 3948.2 or 55293.1 or (3945.1 and 3939.1) or 3939.1 or 160287.1 or 3945.1 or 3948.1',
#  '2HBt2': '9123.1 or 9194.1 or 6566.1',
#  '2HCO3_NAt': '57835.3 or 8671.1 or 57835.2 or 57835.1 or 57835.4',
#  '2OXOADOXm': '(4967.2 and 1738.1 and 8050.1 and 1743.1) or (4967.1 and 1738.1 and 8050.1 and 1743.1)',
#  '2OXOADPTm': '89874.1',
#  '34DHOXPEGOX': '130.1 or 127.1 or (125.1 and 124.1) or 131.1 or (126.1 and 124.1) or 128.1 or 137872.1 or (125.1 and 126.1)',
#  '34DHPHAMT': '1312.1 or 1312.2',
#  '34DHPHEt': '117247.1',
#  '34DHPLACOX': '218.1 or 222.1 or 220.1 or 221.1',
#  '34DHPLACOX_NADP_': '222.1 or 221.1 or 218.1',
#  '34DHXMANDACOX': '221.1 or 218.1 or 220.1',
#  '34DHXMANDACOX_NADP_': '221.1 or 222.1',
#  '34HPPOR': '3242.1',
#  '3AIBTm': '18.1 or 18.2',
#  '3AIBtmi': '18.1 or 18.2',
#  '3DSPHR': '2531.1',
#  '3HAO': '23498.1',
#  '3HBCDm': '55268.1',
#  '3HKYNAKGAT': '51166.1 or 883.1 or 51166.2',
#  '3HLYTCL': '1644.1',
#  '3HPCOAHYD': '26275.1 or 26275.2',
#  '3HXKYNDCL': '1644.1',
#  '3HXKYNOXDA': '4128.1 or 4129.1',
#  '3M4HDXPAC': '218.1 or 221.1 or 222.1 or 220.1',
#  '3MOX4HOXPGALDOX': '222.1 or 220.1 or 221.1 or 218.1',
#  '3MOX4HOXPGALDOX_NADP_': '222.1 or 220.1 or 221.1 or 218.1',
#  '3MOXTYROX': '4128.1 or 4129.1',
#  '3NTD7l': '53.1 or 55.1 or 51205.1 or 54.1',
#  '3SALAASPm': '10165.1 or 8604.1',
#  '3SALACBOXL': '51380.1 or 2571.1 or 2572.1 or 2571.2',
#  '3SALATAi': '2805.1',
#  '3SALATAim': '2806.1',
#  '41R1H2MAE12BOOX': '4128.1 or 4129.1',
#  '41R2A1H12BOOX': '4128.1 or 4129.1',
#  '42A12BOOX': '4129.1 or 8639.1 or 26.1 or 314.2 or 314.1 or 4128.1',
#  '4HGLSDm': '8659.1 or 8659.2',
#  '4HOXPACDOX_NADP_': '222.1 or 220.1 or 221.1 or 218.1',
#  '4NPHSULT': '6799.1 or 6817.3 or 6799.2 or 6818.2 or 6817.2 or 6818.1 or 6817.1 or 6817.4 or 6818.3 or 6817.5',
#  '5ADTSTSTERONEGLCte': '4363.1',
#  '5ADTSTSTERONESULT': '6822.1 or 6818.1',
#  '5FTHFt2': '6573.1 or 6573.2',
#  '5HLTDL': '1644.1',
#  '5HOXINDACTO2OX': '316.1',
#  '5HOXINDACTOXm': '8659.2 or 219.1 or 8659.1 or 217.1',
#  '5HOXINOXDA': '4128.1 or 4129.1',
#  '5HTRPDOX': '3620.1',
#  '5HTRPVESSEC': '6570.1 or 6571.1',
#  '5HXKYNDCL': '1644.1',
#  '5HXKYNOXDA': '4128.1 or 4129.1',
#  '5MTHFt': '2348.5 or 2348.3 or 2348.1 or 2348.6 or 2352.1 or 2348.4 or 2348.2',
#  '5MTHFt2': '6573.1 or 6573.2',
#  'A_MANASE': '4123.1',
#  'A_MANASEly': '4125.1',
#  'A4GALTc': '53947.1',
#  'A4GALTg': '53947.1',
#  'A4GNT1g': '51146.1',
#  'A4GNT2g': '51146.1',
#  'AACTOOR': '8639.1',
#  'AATAi': '51166.1 or 51166.2',
#  'ABO1g': '28.1',
#  'ABO2g': '28.1',
#  'ABO3g': '28.1',
#  'ABO4g': '28.1',
#  'ABO5g': '28.1',
#  'ABO6g': '28.1',
#  'ABO7g': '28.1',
#  'ABO8g': '28.1',
#  'ABO9g': '28.1',
#  'ABTArm': '18.1 or 18.2',
#  'ABUTt2rL': '206358.1',
#  'ABUTt4_2_r': '6529.1 or 6538.1 or 6540.1 or 6539.1',
#  'ACACT10m': '38.1 or 3032.1 or 10449.1',
#  'ACACT1rm': '(3030.1 and 3032.1) or 38.1',
#  'ACACT1x': '39.1',
#  'ACACt2m': '6566.1',
#  'ACACT4p': '30.1',
#  'ACACT5p': '30.1',
#  'ACACT6p': '30.1',
#  'ACACT7p': '30.1',
#  'ACACT8p': '30.1',
#  'ACACT9p': '30.1',
#  'ACCOACm': '32.1',
#  'ACCOAgt': '9197.1',
#  'ACCOALm': '84532.1 or 79611.1',
#  'ACCOAtr': '9197.1',
#  'ACETONEt2': '6566.1 or 9123.1 or 9194.1',
#  'ACETONEt2m': '6566.1',
#  'ACGAM6PSi': '64841.1',
#  'ACGAMK': '55577.1',
#  'ACGAMPM': '5238.1',
#  'ACGPID': '9487.1',
#  'ACGSm': '162417.1',
#  'ACHEe': '43.1 or 43.2',
#  'ACHVESSEC': '6572.1',
#  'ACITL': '47.1 or 47.2',
#  'ACNAM9PL': '54187.1',
#  'ACNAM9PL2': '54187.1',
#  'ACNAMlt': '26503.1',
#  'ACNAMPH': '140838.1 or 54.1 or 51205.1',
#  'ACOAD10m': '36.1 or 34.1',
#  'ACOAD1fm': '80724.1 or 36.1 or 35.1 or 34.1 or 84129.1 or 27034.1 or 28976.1',
#  'ACOAD8m': '3712.1',
#  'ACOAD9m': '34.1 or 27034.1',
#  'ACOAHi': '134526.1',
#  'ACOAO7p': '51.1 or 51.2',
#  'ACODA': '95.1',
#  'ACONTm': '50.1 or 48.1',
#  'ACOX22x': '8309.1',
#  'ACOX2x': '8309.1',
#  'ACP1_FMN_': '52.1 or 52.3 or 52.2 or 55.1 or 51205.1 or 54.1',
#  'ACRNtm': '788.1',
#  'ACS2': '55902.1 or 65985.1 or 55902.2',
#  'ACSm': '84532.1',
#  'ACSOMT': '438.1',
#  'ACSRTNMT': '438.1',
#  'ACTLMO': '1571.1',
#  'ACTNMO': '1571.1',
#  'ADA': '100.1',
#  'ADAe': '100.1',
#  'ADEt': '3177.1',
#  'ADEtl': '55315.1',
#  'ADK1m': '205.3 or 205.1 or 204.1 or 204.3 or 204.2 or 205.2',
#  'ADK3': '26289.1 or 26289.2',
#  'ADK3m': '50808.1',
#  'ADKd': '26289.2 or 26289.1',
#  'ADMDC': '262.1',
#  'ADNCYC': '112.1 or 55811.1 or 109.1 or 112.2 or 114.1 or 108.1 or 113.1 or 107.1 or 196883.1 or 115.1 or 111.1',
#  'ADNt': '3177.1 or 2030.1',
#  'ADNt4': '9154.2 or 9154.1 or 64078.1 or 9153.1',
#  'ADNtl': '55315.1',
#  'ADNtm': '2030.1',
#  'ADPGLC': '11164.1',
#  'ADPMAN': '11164.1',
#  'ADPRDPm': '53343.1 or 53343.3 or 53343.2',
#  'ADPRIBt': '952.1',
#  'ADRNCPT1': '1375.1 or 1375.3 or 1375.4 or 126129.1 or 1374.1 or 1375.2',
#  'ADRNCPT2': '1376.1',
#  'ADRNCRNt': '788.1 or 788.1',
#  'ADRNLPVESSEC': '6570.1 or 6571.1',
#  'ADSELK': '9061.1 or 9060.1',
#  'ADSK': '9060.1 or 9061.1',
#  'ADSL1': '158.1 or 158.2',
#  'ADSL2': '158.1 or 158.2',
#  'AG13T10g': '79369.1 or 10678.1 or 11041.1 or 146712.1 or 374907.1 or 93010.1 or 374907.2 or 10331.1 or 10678.2',
#  'AG13T11g': '79369.1 or 374907.1 or 11041.1 or 146712.1 or 374907.2 or 93010.1 or 10331.1 or 10678.1 or 10678.2',
#  'AG13T12g': '79369.1 or 374907.1 or 11041.1 or 146712.1 or 374907.2 or 93010.1 or 10331.1 or 10678.1 or 10678.2',
#  'AG13T13g': '79369.1 or 374907.1 or 11041.1 or 146712.1 or 374907.2 or 93010.1 or 10331.1 or 10678.1 or 10678.2',
#  'AG13T14g': '79369.1 or 374907.1 or 11041.1 or 146712.1 or 374907.2 or 93010.1 or 10331.1 or 10678.1 or 10678.2',
#  'AG13T15g': '79369.1 or 374907.1 or 11041.1 or 146712.1 or 374907.2 or 93010.1 or 10331.1 or 10678.1 or 10678.2',
#  'AG13T16g': '79369.1 or 10678.1 or 11041.1 or 146712.1 or 374907.1 or 93010.1 or 374907.2 or 10678.2 or 10331.1',
#  'AG13T17g': '10678.2 or 11041.1 or 10678.1 or 374907.2 or 93010.1 or 374907.1 or 146712.1 or 79369.1 or 10331.1',
#  'AG13T18g': '10678.2 or 11041.1 or 10678.1 or 374907.2 or 93010.1 or 374907.1 or 146712.1 or 79369.1 or 10331.1',
#  'AG13T1g': '11041.1 or 10678.1 or 93010.1 or 374907.2 or 374907.1 or 146712.1 or 10331.1 or 10678.2 or 79369.1',
#  'AG13T2g': '79369.1 or 374907.1 or 11041.1 or 146712.1 or 374907.2 or 93010.1 or 10331.1 or 10678.1 or 10678.2',
#  'AG13T3g': '10331.1 or 11041.1 or 374907.2 or 10678.1 or 79369.1 or 374907.1 or 10678.2 or 93010.1 or 146712.1',
#  'AG13T4g': '11041.1 or 10678.1 or 93010.1 or 10331.1 or 374907.1 or 146712.1 or 374907.2 or 10678.2 or 79369.1',
#  'AG13T5g': '79369.1 or 374907.1 or 11041.1 or 146712.1 or 374907.2 or 93010.1 or 10331.1 or 10678.1 or 10678.2',
#  'AG13T6g': '79369.1 or 374907.1 or 11041.1 or 146712.1 or 374907.2 or 93010.1 or 10331.1 or 10678.1 or 10678.2',
#  'AG13T7g': '79369.1 or 374907.1 or 11041.1 or 146712.1 or 374907.2 or 93010.1 or 10331.1 or 10678.1 or 10678.2',
#  'AG13T8g': '79369.1 or 374907.1 or 11041.1 or 146712.1 or 374907.2 or 93010.1 or 10331.1 or 10678.1 or 10678.2',
#  'AG13T9g': '146712.1 or 79369.1 or 10331.1 or 374907.1 or 10678.2 or 374907.2 or 10678.1 or 11041.1 or 93010.1',
#  'AGMTm': '79814.1',
#  'AGPAT1': '10555.1 or 137964.1 or 56895.1 or 56894.2 or 56894.1 or 55326.1 or 10554.1 or 129642.1',
#  'AGPRim': '5832.1',
#  'AGPSx': '8540.1',
#  'AGTim': '64902.1 or 64850.1',
#  'AGTix': '189.1',
#  'AHANDROSTANGLCte': '4363.1',
#  'AHEXASE2ly': '3073.1 or 3074.1 or (3073.1 and 3074.1)',
#  'AHEXASEly': '3073.1 or 3074.1 or (3073.1 and 3074.1)',
#  'AIRCr': '10606.1',
#  'AKGDm': '(4967.2 and 1738.1 and 8050.1 and 1743.1) or (4967.1 and 1738.1 and 8050.1 and 1743.1)',
#  'AKGMALtm': '8402.1 or 1468.1',
#  'AKGt4_3': '64849.1 or 64849.2',
#  'AKR1C1': '1645.1',
#  'AKR1C41': '1109.1',
#  'AKR1C42': '1109.1',
#  'AKR1D': '6718.1',
#  'AKR1D2': '6718.1',
#  'ALAASNNaEx': '6510.1',
#  'ALACYSNaEx': '6509.1 or 6510.1',
#  'ALADGLNexR': '56301.1 and 6520.1',
#  'ALADGLYexR': '56301.1 and 6520.1',
#  'ALAGLNexR': '6520.1 and 56301.1',
#  'ALAGLNNaEx': '6510.1',
#  'ALAGLYexR': '56301.1 and 6520.1',
#  'ALASERNaEx': '6509.1 or 6510.1',
#  'ALASm': '212.1 or 23464.1 or 211.2 or 211.1',
#  'ALAt2rL': '206358.1',
#  'ALAt4': '54407.1 or 6542.1 or 11254.1 or 6541.1 or 81539.1 or 55089.1 or 84889.1 or (340024.1 and 57393.1) or (340024.1 and 59272.1)',
#  'ALATA_L': '2875.1 or 84706.1',
#  'ALATHRNaEx': '6509.1 or 6510.1',
#  'ALAtN1': '92745.1 or 10991.1',
#  'ALCD21_D': '127.1 or 284273.2 or 125.1 or 128.1 or 131.1 or (125.1 and 124.1) or 124.1 or 130.1 or 137872.1 or (125.1 and 126.1) or (126.1 and 124.1) or 284273.1 or 126.1',
#  'ALCD21_L': '130.1 or 125.1 or (125.1 and 124.1) or 128.1 or 126.1 or 284273.2 or 137872.1 or 127.1 or 124.1 or (126.1 and 124.1) or 284273.1 or (125.1 and 126.1) or 131.1',
#  'ALCD22_D': '126.1 or 137872.1 or (126.1 and 124.1) or 127.1 or 130.1 or 284273.1 or (125.1 and 124.1) or 128.1 or 124.1 or 125.1 or 284273.2 or 131.1 or (125.1 and 126.1)',
#  'ALCD22_L': '126.1 or 137872.1 or (126.1 and 124.1) or 127.1 or 130.1 or 284273.1 or (125.1 and 124.1) or 128.1 or 124.1 or 125.1 or 284273.2 or 131.1 or (125.1 and 126.1)',
#  'ALCD2if': '(125.1 and 126.1) or 137872.1 or (125.1 and 124.1) or 127.1 or 130.1 or 284273.1 or 126.1 or 124.1 or 128.1 or 125.1 or 126.1 or 284273.2 or 131.1 or (126.1 and 124.1)',
#  'ALCD2yf': '10327.1 or 10327.2',
#  'ALDD20x': '216.1 or 8854.2 or 501.1 or 8854.1 or 223.1 or 224.1 or 8854.3',
#  'ALDD20xm': '219.1 or 8659.1 or 217.1 or 8659.2',
#  'ALDD21': '224.1',
#  'ALDD2xm': '219.1 or 217.1',
#  'ALDD2y': '223.1 or 221.1 or 218.1 or 8854.1 or 8854.3 or 222.1 or 8854.2 or 224.1 or 219.1',
#  'ALKP': '248.1 or 251.1 or 249.1 or 250.1',
#  'ALOX12': '239.1',
#  'ALOX12R': '242.1',
#  'ALOX15': '247.1 or 246.1',
#  'ALOX5': '240.1',
#  'ALOX52': '240.1',
#  'ALR2': '10327.2 or 8574.1 or 10327.1 or 231.1',
#  'ALR3': '10327.2 or 8574.1 or 10327.1 or 231.1',
#  'AMACR2p': '23600.1 or 23600.2',
#  'AMACR2r': '23600.1 or 23600.2',
#  'AMACRp': '23600.2 or 23600.1',
#  'AMACRr': '23600.2 or 23600.1',
#  'AMETt2m': '115286.3 or 115286.2 or 115286.1',
#  'AMPDA': '271.2 or 270.1 or 271.1 or 272.1 or 271.3',
#  'AMPTASECGe': '290.1',
#  'AMY1e': '6520.1 or 280.1 or 278.1 or 276.1 or 277.1 or (6519.1 and 11136.1) or 276.2 or 279.1',
#  'AMY2e': '6520.1 or 280.1 or 278.1 or 276.1 or 277.1 or (6519.1 and 11136.1) or 276.2 or 279.1',
#  'ANDRSTRNGLCte': '4363.1',
#  'AP4AH1': '318.1 or 318.3 or 318.2',
#  'APAT2rm': '18.1 or 18.2',
#  'APRTO2': '4128.1 or 4129.1',
#  'ARABR': '10327.2 or 8574.1 or 10327.1 or 231.1',
#  'ARACHCPT1': '1375.3 or 1374.1 or 1375.2 or 1375.4 or 1375.1 or 126129.1',
#  'ARACHCPT2': '1376.1',
#  'ARACHCRNt': '788.1',
#  'ARACHDt2': '10998.1',
#  'ARGDCm': '113451.1',
#  'ARGLYSex': '9057.1 and 6520.1',
#  'ARGNm': '384.1',
#  'ARGSS': '445.1 or 445.2',
#  'ARGt4': '11254.1',
#  'ARGtm': '83884.1 or 10166.1',
#  'ARSA': '410.1',
#  'ASAH1': '427.1 or 427.2',
#  'ASCBt4': '9962.2 or 9963.1 or 9962.1 or 9963.2',
#  'ASNALANaEx': '6510.1',
#  'ASNCYSNaEx': '6510.1',
#  'ASNGLNNaEx': '6510.1',
#  'ASNNm': '80150.1',
#  'ASNS1': '440.1 or 440.3 or 440.2',
#  'ASNSERNaEx': '6510.1',
#  'ASNt4': '81539.1 or 11254.1 or 54407.1 or 55089.1 or (340024.1 and 57393.1) or (340024.1 and 59272.1)',
#  'ASNTHRNaEx': '6510.1',
#  'ASNtN1': '92745.1 or 10991.1',
#  'ASPCTr': '790.1',
#  'ASPDt6': '6511.1 or 6505.1 or 6507.1 or 6506.1 or 6512.1',
#  'ASPGLUm': '8604.1 or 10165.1',
#  'ASPt6': '6511.1 or 6505.1 or 6507.1 or 6506.1 or 6512.1',
#  'ASPTAm': '2806.1',
#  'ATPasel': '((50617.1 and 533.1 and 527.1 and 8992.1 and 245972.1) or (50617.1 and 533.1 and 527.1 and 8992.1 and 9114.1) or (533.1 and 527.1 and 8992.1 and 535.1 and 245972.1) or (533.1 and 527.1 and 8992.1 and 535.1 and 9114.1) or (533.1 and 527.1 and 8992.1 and 50617.3 and 245972.1) or (533.1 and 527.1 and 8992.1 and 10312.1 and 9114.1) or (533.1 and 527.1 and 8992.1 and 245972.1 and 50617.2) or (533.1 and 527.1 and 8992.1 and 9114.1 and 23545.1) or (533.1 and 527.1 and 8992.1 and 10312.2 and 245972.1) or (533.1 and 527.1 and 8992.1 and 50617.3 and 9114.1) or (533.1 and 527.1 and 8992.1 and 245972.1 and 23545.1) or (533.1 and 527.1 and 8992.1 and 9114.1 and 50617.2) or (533.1 and 527.1 and 8992.1 and 10312.1 and 245972.1) or (533.1 and 527.1 and 8992.1 and 10312.2 and 9114.1)) and ((51382.1 and 9296.1 and 529.1 and 245973.1 and 523.1 and 51606.1 and 9550.1 and 526.1) or (51382.1 and 9296.1 and 127124.1 and 245973.1 and 525.1 and 90423.1 and 51606.2 and 523.1) or (51382.1 and 51606.3 and 9296.1 and 534.2 and 90423.1 and 523.1 and 526.1 and 528.2) or (51382.1 and 9296.1 and 245973.1 and 534.2 and 523.1 and 90423.1 and 51606.1 and 526.1) or (51382.1 and 9296.1 and 534.1 and 51606.2 and 529.1 and 528.1 and 523.1 and 526.1) or (51382.1 and 51606.3 and 9296.1 and 534.1 and 529.1 and 523.1 and 528.2 and 526.1) or (51382.1 and 51606.3 and 9296.1 and 127124.1 and 529.1 and 525.1 and 523.1 and 528.2) or (51382.1 and 9296.1 and 245973.1 and 90423.1 and 127124.2 and 51606.2 and 523.1 and 526.1) or (51382.1 and 9296.1 and 127124.1 and 529.1 and 525.1 and 523.1 and 51606.1 and 528.2) or (51382.1 and 9296.1 and 51606.2 and 529.1 and 245973.1 and 534.2 and 525.1 and 523.1) or (51382.1 and 9296.1 and 534.1 and 528.1 and 523.1 and 90423.1 and 51606.1 and 526.1) or (51382.1 and 51606.3 and 9296.1 and 523.1 and 90423.1 and 9550.1 and 528.2 and 526.1) or (51382.1 and 51606.3 and 9296.1 and 534.1 and 245973.1 and 525.1 and 90423.1 and 523.1) or (51382.1 and 9296.1 and 534.1 and 525.1 and 529.1 and 528.1 and 523.1 and 51606.1) or (51382.1 and 9296.1 and 90423.1 and 127124.2 and 51606.2 and 523.1 and 526.1 and 528.2) or (51382.1 and 51606.3 and 9296.1 and 534.1 and 90423.1 and 528.1 and 523.1 and 526.1) or (51382.1 and 9296.1 and 51606.2 and 529.1 and 525.1 and 523.1 and 127124.2 and 528.2) or (51382.1 and 51606.3 and 9296.1 and 534.1 and 529.1 and 528.1 and 525.1 and 523.1) or (51382.1 and 9296.1 and 529.1 and 523.1 and 51606.1 and 127124.2 and 528.2 and 526.1) or (51382.1 and 51606.3 and 9296.1 and 534.2 and 525.1 and 90423.1 and 528.1 and 523.1) or (51382.1 and 9296.1 and 534.2 and 90423.1 and 51606.2 and 523.1 and 526.1 and 528.2) or (51382.1 and 51606.3 and 9296.1 and 525.1 and 523.1 and 90423.1 and 9550.1 and 528.2) or (51382.1 and 51606.3 and 9296.1 and 534.1 and 525.1 and 90423.1 and 528.1 and 523.1) or (51382.1 and 9296.1 and 127124.1 and 245973.1 and 525.1 and 523.1 and 90423.1 and 51606.1) or (51382.1 and 9296.1 and 245973.1 and 525.1 and 90423.1 and 127124.2 and 51606.2 and 523.1) or (51382.1 and 9296.1 and 534.1 and 525.1 and 51606.2 and 529.1 and 523.1 and 528.2) or (51382.1 and 51606.3 and 9296.1 and 127124.1 and 529.1 and 528.1 and 523.1 and 526.1) or (51382.1 and 51606.3 and 9296.1 and 127124.1 and 90423.1 and 523.1 and 526.1 and 528.2) or (51382.1 and 9296.1 and 127124.1 and 529.1 and 523.1 and 51606.1 and 528.2 and 526.1) or (51382.1 and 51606.3 and 9296.1 and 525.1 and 90423.1 and 127124.2 and 528.1 and 523.1) or (51382.1 and 9296.1 and 90423.1 and 127124.2 and 51606.2 and 528.1 and 523.1 and 526.1) or (51382.1 and 9296.1 and 245973.1 and 534.2 and 525.1 and 90423.1 and 51606.2 and 523.1) or (51382.1 and 51606.3 and 9296.1 and 127124.1 and 529.1 and 245973.1 and 523.1 and 526.1) or (51382.1 and 51606.3 and 9296.1 and 245973.1 and 523.1 and 90423.1 and 9550.1 and 526.1) or (51382.1 and 9296.1 and 528.1 and 534.2 and 523.1 and 90423.1 and 51606.1 and 526.1) or (51382.1 and 9296.1 and 127124.1 and 525.1 and 90423.1 and 51606.2 an ...
#  'ATPH1e': '954.1 or 954.2 or 953.1 or 956.1 or 955.1 or 957.1',
#  'ATPH2e': '954.2 or 954.1 or 953.1 or 956.1 or 955.1 or 957.1 or 377841.1',
#  'ATPtm': '291.1 or 293.1 or 292.1',
#  'B_MANNASEly': '4126.1',
#  'B3GALT3g': '8706.4 or 8706.1 or 8706.3 or 8706.2',
#  'B3GALT41g': '8705.1',
#  'B3GALT42g': '8705.1',
#  'B3GALT43g': '8705.1',
#  'B3GALT44g': '8705.1',
#  'B3GALT5g': '10317.4 or 10317.1 or 10317.3 or 10317.2 or 10317.5',
#  'B3GNT11g': '10678.1',
#  'B3GNT12g': '10678.1 or 10678.2',
#  'B3GNT310g': '10331.1',
#  'B3GNT311g': '10331.1',
#  'B3GNT312g': '10331.1',
#  'B3GNT313g': '10331.1',
#  'B3GNT314g': '10331.1',
#  'B3GNT315g': '10331.1',
#  'B3GNT31g': '10331.1',
#  'B3GNT32g': '10331.1',
#  'B3GNT33g': '10331.1',
#  'B3GNT34g': '10331.1',
#  'B3GNT35g': '10331.1',
#  'B3GNT36g': '10331.1',
#  'B3GNT37g': '10331.1',
#  'B3GNT39g': '10331.1',
#  'B3GNT51g': '84002.1',
#  'BAAT1x': '570.1',
#  'BAAT2x': '570.1',
#  'BAAT3x': '570.1',
#  'BAAT4x': '570.1',
#  'BACCL': '3141.1',
#  'BACCLm': '3141.1',
#  'BALAVECSEC': '140679.1',
#  'BAMPPALDOX': '8854.2 or 501.1 or 216.1 or 224.1 or 8854.3 or 223.1 or 8854.1',
#  'BAMPPALDOXm': '8659.2 or 217.1 or 8659.1 or 219.1',
#  'BBHOX': '8424.1',
#  'BCDO': '53630.1',
#  'BDG2HCGHD': '57733.1',
#  'BDHm': '622.2 or 622.3 or 622.1',
#  'BDMT_L': '56052.1',
#  'BDMT_U': '56052.1',
#  'BHMT': '23743.1 or 635.1',
#  'BILDGLCURt': '10599.1',
#  'BILDGLCURte': '4363.1 or 1244.1 or 8714.1',
#  'BILGLCURt': '10599.1 or 28234.1',
#  'BILGLCURte': '4363.1',
#  'BILIRED': '645.1 or 644.1',
#  'BILIRUBt2': '10599.1',
#  'BMTer_L': '9488.1',
#  'BMTer_U': '9488.1',
#  'BPNT2': '10380.1',
#  'BTND1': '686.1',
#  'BTND1n': '686.1',
#  'BTNDe': '686.1',
#  'BTNDm': '686.1',
#  'BTNPL': '3141.1',
#  'BTNPLm': '3141.1',
#  'BTNt2': '6566.1',
#  'BTNt2m': '6566.1',
#  'BTNt3i': '8884.1',
#  'BTNt4i': '80704.1',
#  'BUP2': '51733.1',
#  'BUTt2m': '6566.1',
#  'C14STRr': '7108.1',
#  'C160CPT1': '126129.1 or 1375.3 or 1374.1 or 1375.2 or 1375.1',
#  'C160CPT2': '1376.1 or 1374.1',
#  'C160CRNt': '788.1',
#  'C161CPT1': '1375.1 or 1375.3 or 1375.4 or 126129.1 or 1374.1 or 1375.2',
#  'C161CPT12': '126129.1 or 1375.3 or 1375.1 or 1375.2 or 1374.1 or 1375.4',
#  'C161CPT2': '1376.1',
#  'C161CPT22': '1376.1',
#  'C161CRN2t': '788.1',
#  'C161CRNt': '788.1',
#  'C180CPT1': '1375.4 or 1375.2 or 126129.1 or 1375.1 or 1374.1 or 1375.3',
#  'C180CPT2': '1376.1',
#  'C180CRNt': '788.1',
#  'C181CPT1': '126129.1 or 1375.3 or 1374.1 or 1375.2 or 1375.1 or 1375.4',
#  'C181CPT2': '1376.1',
#  'C181CRNt': '788.1',
#  'C204CPT1': '1374.1 or 1375.4 or 1375.1 or 1375.3 or 1375.2 or 126129.1',
#  'C204CPT2': '1376.1',
#  'C204CRNt': '788.1',
#  'C226CPT1': '126129.1 or 1375.3 or 1374.1 or 1375.2 or 1375.1 or 1375.4',
#  'C226CPT2': '1376.1',
#  'C2M26DCOAHLm': '(3030.1 and 3032.1) or 549.1',
#  'C2M26DCOAHLx': '1891.1 or 1962.1',
#  'C3STDH1Pr': '50814.1',
#  'C3STDH1r': '50814.1',
#  'C3STKR2r': '3295.1',
#  'C4STMO1r': '6307.1',
#  'C4STMO2Pr': '50814.1',
#  'C4STMO2r': '6307.1 or 50814.1',
#  'CAATPS': '492.1 or 491.1 or 490.1 or 493.1',
#  'CAT2p': '847.1',
#  'CAt7r': '6547.6 or 6547.4 or 6547.2 or 6546.1 or 6547.1 or 6547.5 or 6543.1 or 6547.3',
#  'CATm': '847.1',
#  'CATp': '847.1',
#  'CBL2tm': '166785.1',
#  'CBLATm': '166785.1',
#  'CBPPer': '2538.1 or 57818.1 or 92579.1',
#  'CBPSam': '1373.1 or 1373.2',
#  'CBR1': '873.1',
#  'CBR2': '873.1',
#  'CDIPTr': '10423.1 or 10423.2',
#  'CDS': '1040.1 or 8760.1',
#  'CDSm': '1040.1 or 8760.1',
#  'CEPTC': '10390.1 or 56994.1',
#  'CEPTE': '10390.1',
#  'CERK': '64781.1 or 64781.2',
#  'CERT1gt': '10087.1',
#  'CERT1rt': '10087.1',
#  'CERT2gt': '10087.1',
#  'CERT2rt': '10087.1',
#  'CGLYt3_2_': '6565.1',
#  'CH25H': '9023.1',
#  'CHAT': '1103.4 or 1103.2 or 1103.3 or 1103.1',
#  'CHATn': '1103.4 or 1103.1 or 1103.3 or 1103.2',
#  'CHLP': '162466.1',
#  'CHLPCTD': '5130.1 or 9468.1',
#  'CHOLATEt': '6579.1 or 10599.1',
#  'CHOLATEt2': '6554.1 or 6555.1',
#  'CHOLATEt3': '8714.3 or 8647.1 or 8714.2 or 8714.1',
#  'CHOLD2m': '55349.1',
#  'CHOLK': '1120.2 or 1119.1 or 1120.1 or 1119.2',
#  'CHOLt4': '60482.1',
#  'CHOLtu': '6582.1 or 6584.1 or 6582.2',
#  'CHSTEROLSULT': '6820.1 or 6818.1',
#  'CHSTEROLt1': '10948.1',
#  'CHSTEROLtg': '19.1',
#  'CHTNASE': '27159.1 or 54682.1 or 1118.1',
#  'CHTNASEe': '27159.2',
#  'CITRtm': '83884.1 or 10166.1',
#  'CITt4_2': '9058.1',
#  'CITtam': '6576.1',
#  'CITtbm': '6576.1',
#  'CK': '1159.1 or 1160.1 or 548596.1',
#  'CKc': '1152.1 or 1158.1',
#  'CLFORtex': '5172.1',
#  'CLHCO3tex2': '65010.1 or 65010.3 or 65010.2',
#  'CLI2tex': '5172.1',
#  'CLOHtex2': '65010.1 or 65010.3 or 65010.2',
#  'CLOXAtex2': '65010.1 or 65010.3 or 65010.2',
#  'CLPNDCPT1': '1375.1 or 1375.3 or 1375.4 or 126129.1 or 1374.1 or 1375.2',
#  'CLPNDCPT2': '1376.1',
#  'CLPNDCRNt': '788.1',
#  'CLS_hs': '54675.1',
#  'CMPACNAtg': '10559.1',
#  'CMPSAS': '55907.1',
#  'CMPSASn': '55907.1',
#  'COAtm': '8034.1',
#  'COKECBESr': '8824.1',
#  'COQ3m': '51805.1',
#  'COQ6m': '51004.1 or 51004.2',
#  'COQ7m': '10229.1',
#  'CORE2GTg': '9245.1 or 2650.1 or 51301.1',
#  'CORE3GTg': '192134.1',
#  'CORE4GTg': '9245.1',
#  'CORE6GTg': '2650.1',
#  'CPCTDTX': '9468.1 or 5130.1',
#  'CREATt4_2_r': '6535.1 or 386757.1',
#  'CRNCARtp': '1384.1',
#  'CRNt': '6584.1',
#  'CRNtHa': '6583.1',
#  'CRNtim': '788.1',
#  'CRNtuNa': '6584.1',
#  'CSm': '1431.1 or 1431.2',
#  'CSNAT2m': '1384.1',
#  'CSNAT2x': '54677.1 or 1384.2',
#  'CSNAT3x': '1384.2',
#  'CSNATer': '1384.3',
#  'CSNATm': '1384.1',
#  'CSNATp': '1384.2',
#  'CSNATr': '1384.1',
#  'CSNt': '3177.1',
#  'CYSALANaEx': '6509.1 or 6510.1',
#  'CYSASNNaEx': '6510.1',
#  'CYSGLNNaEx': '6510.1',
#  'CYSGLUexR': '(6520.1 and 56301.1) or (8140.1 and 6520.1)',
#  'CYSGLYexR': '(6520.1 and 23428.1) or (6520.1 and 23428.2) or (56301.1 and 6520.1)',
#  'CYSO': '1036.1',
#  'CYSSERNaEx': '6509.1 or 6510.1',
#  'CYSt4': '11254.1 or 54407.1 or (340024.1 and 57393.1) or (340024.1 and 59272.1)',
#  'CYSTA': '2805.1',
#  'CYSTAm': '2806.1',
#  'CYStec': '124935.1',
#  'CYSTGLUex': '23657.1 and 6520.1',
#  'CYSTHRNaEx': '6509.1 or 6510.1',
#  'CYSTSERex': '6519.1 and 11136.1',
#  'CYTD': '978.1 or 57379.1',
#  'CYTDK1': '7371.1 or 83549.1',
#  'CYTDn': '57379.1',
#  'CYTDt': '3177.1 or 2030.1',
#  'CYTDt4': '9154.1 or 9154.2 or 64078.1',
#  'CYTDtl': '55315.1',
#  'CYTDtm': '2030.1',
#  'CYTK10': '51727.1',
#  'CYTK10n': '51727.1',
#  'CYTK11': '51727.1',
#  'CYTK11n': '51727.1',
#  'CYTK12': '51727.1',
#  'CYTK12n': '51727.1',
#  'CYTK13': '51727.1',
#  'CYTK13n': '51727.1',
#  'CYTK14': '51727.1',
#  'CYTK14n': '51727.1',
#  'CYTK1m': '129607.1',
#  'CYTK1n': '51727.1',
#  'CYTK2n': '51727.1',
#  'CYTK3': '26289.1 or 26289.2',
#  'CYTK3n': '51727.1',
#  'CYTK4': '26289.1 or 26289.2',
#  'CYTK4n': '51727.1',
#  'CYTK5': '51727.1',
#  'CYTK5n': '51727.1',
#  'CYTK6': '51727.1',
#  'CYTK6n': '51727.1',
#  'CYTK7': '51727.1',
#  'CYTK7n': '51727.1',
#  'CYTK8': '51727.1',
#  'CYTK8n': '51727.1',
#  'CYTK9': '51727.1',
#  'CYTK9n': '51727.1',
#  'D3AIBTm': '64902.1',
#  'DADA': '100.1',
#  'DADAe': '100.1',
#  'DADNt4': '3177.1',
#  'DAGK_hs': '9162.1 or 1607.1 or 8525.2 or 160851.1 or 1608.1 or 1607.2 or 8525.1 or 8527.1 or 1606.1 or 160851.2 or 8526.1 or 8525.3 or 1607.1 or 8527.2 or 1609.1',
#  'DAGKn_hs': '8525.1 or 9162.1',
#  'DALAOXx': '1610.1',
#  'DALAt2r': '206358.1',
#  'DALAt2rL': '206358.1',
#  'DARGOp': '1610.1',
#  'DASCBR': '2745.1 or 51022.2 or 51022.1',
#  'DASPO1p': '8528.2 or 8528.1',
#  'DCIm': '1632.1 or 10455.1',
#  'DCK1n': '1633.1',
#  'DCK2n': '1633.1',
#  'DCSPTN1CPT1': '1375.1 or 1375.3 or 1375.4 or 126129.1 or 1374.1 or 1375.2',
#  'DCSPTN1CPT2': '1376.1',
#  'DCSPTN1CRNt': '788.1',
#  'DCT': '1638.1',
#  'DCYTD': '978.1 or 57379.1',
#  'DCYTDn': '57379.1',
#  'DCYTt': '3177.1',
#  'DEBRISOQUINEt': '6582.1 or 6582.2',
#  'DESAT16_2': '6319.1',
#  'DESAT18_10': '9415.1',
#  'DESAT18_3': '6319.1',
#  'DESAT18_4': '6319.1',
#  'DESAT18_5': '6319.1',
#  'DESAT18_6': '9415.1',
#  'DESAT18_7': '9415.1',
#  'DESAT18_8': '9415.1',
#  'DESAT18_9': '9415.1 or 3992.1',
#  'DESAT20_1': '3992.1',
#  'DESAT20_2': '3992.1',
#  'DESAT24_1': '9415.1',
#  'DGAT': '8694.1 or 84649.1',
#  'DGNSKm': '1716.5 or 1716.1 or 1716.4 or 1716.2 or 1716.3',
#  'DGSNt': '3177.1',
#  'DHAAt1r': '6515.1 or 6513.1 or 6517.1',
#  'DHAPA': '8443.1',
#  'DHAPAx': '8443.1',
#  'DHCR241r': '1718.1',
#  'DHCR242r': '1718.1 or 1581.1',
#  'DHCR243r': '1718.1',
#  'DHCR71r': '1717.1',
#  'DHCR72r': '1717.1',
#  'DHCRD1': '8560.1 or 8560.2 or 123099.1',
#  'DHCRD2': '8560.1 or 8560.2 or 123099.1',
#  'DHDPBMTm': '51805.1',
#  'DHEASt': '11309.1 or 6579.1 or 28234.1 or 10599.1',
#  'DHEASULT': '6783.1 or 6822.1 or 6818.1',
#  'DHORD9': '1723.1',
#  'DHPM1': '1807.1 or 1809.1 or 1808.1',
#  'DHPM2': '1807.1',
#  'DINt': '3177.1',
#  'D_LACt2': '9194.1 or 23539.1 or 6566.1 or 9123.1',
#  'D_LACtm': '6566.1',
#  'DLNLCGCPT1': '1375.1 or 1375.3 or 1375.4 or 126129.1 or 1374.1 or 1375.2',
#  'DLNLCGCPT2': '1376.1',
#  'DLNLCGCRNt': '788.1',
#  'DLNLCGt': '10998.1',
#  'DMATTx': '2224.1',
#  'DMGDHm': '29958.1',
#  'DNAMTn': '1787.3 or 1788.2 or 1786.1 or 1787.4 or 1787.6 or 1788.3 or 1789.4 or 1789.2 or 1789.1 or 1787.5 or 1789.3 or 1787.1 or 1788.4 or 1788.1 or 1787.2',
#  'DNAMTSEn': '1787.5 or 1788.4 or 1787.2 or 1787.6 or 1788.2 or 1789.1 or 1787.1 or 1789.4 or 1789.3 or 1788.1 or 1786.1 or 1787.3 or 1789.2 or 1788.3 or 1787.4',
#  'DNDPt10m': '60386.1',
#  'DNDPt11m': '60386.1',
#  'DNDPt12m': '60386.1',
#  'DNDPt13m': '60386.1',
#  'DNDPt14m': '60386.1',
#  'DNDPt15m': '60386.1',
#  'DNDPt16m': '60386.1',
#  'DNDPt17m': '60386.1',
#  'DNDPt18m': '60386.1',
#  'DNDPt19m': '60386.1',
#  'DNDPt1m': '60386.1',
#  'DNDPt20m': '60386.1',
#  'DNDPt21m': '60386.1',
#  'DNDPt22m': '60386.1',
#  'DNDPt23m': '60386.1',
#  'DNDPt24m': '60386.1',
#  'DNDPt25m': '60386.1',
#  'DNDPt26m': '60386.1',
#  'DNDPt27m': '60386.1',
#  'DNDPt28m': '60386.1',
#  'DNDPt29m': '60386.1',
#  'DNDPt2m': '60386.1',
#  'DNDPt30m': '60386.1',
#  'DNDPt31m': '60386.1',
#  'DNDPt32m': '60386.1',
#  'DNDPt33m': '60386.1',
#  'DNDPt34m': '60386.1',
#  'DNDPt35m': '60386.1',
#  'DNDPt36m': '60386.1',
#  'DNDPt37m': '60386.1',
#  'DNDPt38m': '60386.1',
#  'DNDPt39m': '60386.1',
#  'DNDPt3m': '60386.1',
#  'DNDPt40m': '60386.1',
#  'DNDPt41m': '60386.1',
#  'DNDPt42m': '60386.1',
#  'DNDPt43m': '60386.1',
#  'DNDPt44m': '60386.1',
#  'DNDPt45m': '60386.1',
#  'DNDPt46m': '60386.1',
#  'DNDPt47m': '60386.1',
#  'DNDPt48m': '60386.1',
#  'DNDPt49m': '60386.1',
#  'DNDPt4m': '60386.1',
#  'DNDPt50m': '60386.1',
#  'DNDPt51m': '60386.1',
#  'DNDPt52m': '60386.1',
#  'DNDPt53m': '60386.1',
#  'DNDPt54m': '60386.1',
#  'DNDPt55m': '60386.1',
#  'DNDPt56m': '60386.1',
#  'DNDPt57m': '60386.1',
#  'DNDPt58m': '60386.1',
#  'DNDPt59m': '60386.1',
#  'DNDPt5m': '60386.1',
#  'DNDPt60m': '60386.1',
#  'DNDPt61m': '60386.1',
#  'DNDPt62m': '60386.1',
#  'DNDPt63m': '60386.1',
#  'DNDPt6m': '60386.1',
#  'DNDPt7m': '60386.1',
#  'DNDPt8m': '60386.1',
#  'DNDPt9m': '60386.1',
#  'DOLASNT_Ler': '6185.1 and 1650.1 and 6184.1 and 1603.1',
#  'DOLASNT_Uer': '6185.1 and 1650.1 and 6184.1 and 1603.1',
#  'DOLDPP_Ler': '57171.1',
#  'DOLDPP_Uer': '57171.1',
#  'DOLPGT1_Ler': '29929.1',
#  'DOLPGT1_Uer': '29929.1',
#  'DOLPGT2_Ler': '79053.1 or 79053.3 or 79053.2',
#  'DOLPGT2_Uer': '79053.1 or 79053.3 or 79053.2',
#  'DOLPGT3_Ler': '84920.1',
#  'DOLPGT3_Uer': '84920.1',
#  'DOLPMT_L': '(54344.2 and 8818.1 and 8813.1) or (8818.2 and 54344.1 and 8813.1) or (8818.1 and 54344.1 and 8813.1) or (54344.2 and 8818.2 and 8813.1)',
#  'DOLPMT_U': '(54344.2 and 8818.1 and 8813.1) or (8818.2 and 54344.1 and 8813.1) or (8818.1 and 54344.1 and 8813.1) or (54344.2 and 8818.2 and 8813.1)',
#  'DOLPMT1_Ler': '10195.4 or 10195.1 or 10195.3 or 10195.2',
#  'DOLPMT1_Uer': '10195.4 or 10195.1 or 10195.3 or 10195.2',
#  'DOLPMT3_Ler': '79087.1',
#  'DOLPMT3_Uer': '79087.1',
#  'DOPABMO': '26002.1 or 1621.1',
#  'DOPACHRMISO': '7299.1',
#  'DOPAMT': '1312.1 or 1312.2',
#  'DOPASULT': '6799.1 or 6817.3 or 6799.2 or 6818.2 or 6817.2 or 6818.1 or 6817.1 or 6817.4 or 6818.3 or 6817.5',
#  'DOPAt4_2_r': '6530.1 or 6531.1',
#  'DOPAtu': '6581.1 or 6582.2 or 6582.1 or 6584.1',
#  'DOPAVESSEC': '6570.1 or 6571.1',
#  'DORNOp': '1610.1',
#  'DPGase': '669.2 or 5223.1 or 5224.2 or 5224.1 or 669.1',
#  'DPGM': '669.1 or 5223.1 or 5224.2 or 5224.1 or 669.2',
#  'DPMVDx': '4597.1',
#  'DPROOp': '1610.1',
#  'DRPA': '51071.1',
#  'DURAD': '1806.1',
#  'DURAD2': '1806.1',
#  'DURIK1': '7083.1 or 7084.1',
#  'DURIK1m': '7084.1',
#  'DURIt': '3177.1',
#  'DUTPDPm': '1854.1 or 3704.1',
#  'DUTPDPn': '1854.1',
#  'EBP1r': '10682.1',
#  'EBP2r': '10682.1',
#  'ECOAH12m': '1892.1 or (3030.1 and 3032.1)',
#  'ECOAH1m': '549.1 or (3030.1 and 3032.1) or 1892.1',
#  'ECOAH1x': '1891.1 or 1962.1',
#  'ECOAH9m': '1892.1 or (3030.1 and 3032.1)',
#  'EGMESTr': '13.1',
#  'EHGLAT2m': '2806.1',
#  'EHGLATm': '2806.1',
#  'EICOSTETCPT1': '1375.1 or 1375.3 or 1375.4 or 126129.1 or 1374.1 or 1375.2',
#  'EICOSTETCPT2': '1376.1',
#  'EICOSTETCRNt': '788.1',
#  'ELAIDCPT1': '1375.1 or 1375.3 or 1375.4 or 126129.1 or 1374.1 or 1375.2',
#  'ELAIDCPT2': '1376.1',
#  'ELAIDCRNt': '788.1',
#  'ELAIDt': '11001.1',
#  'ENGASE': '64772.1',
#  'ENGASE2': '64772.1',
#  'EPCTX': '5833.1',
#  'ESTRADIOLGLCt': '28234.1 or 28231.1 or 10599.1 or 6579.1 or 53919.1',
#  'ESTRADIOLGLCt2': '10257.1',
#  'ESTRIOLGLCte': '4363.1',
#  'ESTRONEGLCt': '8714.1 or 8714.3 or 8714.2',
#  'ESTRONESt': '11309.1 or 10599.1 or 53919.1 or 6579.1 or 28232.1 or 28231.1 or 28234.1',
#  'ESTRONESt2': '6554.1',
#  'ESTSULT': '6783.1 or 6817.4 or 6817.1 or 6817.3 or 6817.2 or 6817.5 or 6818.1',
#  'ETF': '(2109.2 and 2108.1) or (2109.1 and 2108.1)',
#  'ETFQO': '2110.1',
#  'ETHAK': '1119.2 or 55500.1 or 1119.1 or 55224.1 or 1120.1',
#  'ETHP': '162466.1',
#  'ETOHMO': '1571.1',
#  'F1PGT': '8790.1 or 51086.1',
#  'F6Tg': '2530.4 or 2530.1 or 2530.3 or 2530.2 or 2530.5',
#  'FA120ACPH': '55301.1',
#  'FA140ACPH': '55301.1',
#  'FA141ACPH': '55301.1',
#  'FA160ACPH': '55301.1 or 2194.1',
#  'FA161ACPH': '55301.1',
#  'FA180ACPH': '55301.1',
#  'FA181ACPH': '55301.1',
#  'FA182ACPH': '55301.1',
#  'FACOAL140i': '2181.1',
#  'FACOAL150': '2182.1 or 2180.1 or 2181.2 or 2181.1',
#  'FACOAL160i': '2181.2 or 51703.1 or 2180.1 or 2181.1 or 2182.1 or 81616.1',
#  'FACOAL170': '2182.1 or 2180.1 or 2181.2 or 2181.1',
#  'FACOAL180i': '2181.2 or 51703.1 or 2181.1 or 2180.1',
#  'FACOAL1812': '2180.1',
#  'FACOAL1813': '2180.1',
#  'FACOAL181i': '2180.1 or 2181.2 or 2181.1 or 2182.1 or 81616.1',
#  'FACOAL1821': '2180.1 or 2182.1 or 81616.1 or 2181.1',
#  'FACOAL1822': '2180.1',
#  'FACOAL1831': '2180.1 or 2182.1 or 2181.1 or 81616.1 or 23305.1 or 51703.1',
#  'FACOAL1832': '2180.1',
#  'FACOAL184': '2180.1',
#  'FACOAL191': '11001.1',
#  'FACOAL200': '2180.1',
#  'FACOAL203': '2180.1',
#  'FACOAL204': '2181.2 or 2181.1 or 2180.1 or 2182.1 or 2182.2 or 81616.1',
#  'FACOAL2042': '2180.1',
#  'FACOAL205': '2180.1',
#  'FACOAL206': '11001.1',
#  'FACOAL224': '2180.1',
#  'FACOAL2251': '2180.1',
#  'FACOAL2252': '2180.1',
#  'FACOAL226': '2180.1',
#  'FACOAL240': '2180.1',
#  'FACOAL241': '2180.1',
#  'FACOAL244_1': '2180.1',
#  'FACOAL245_1': '2180.1',
#  'FACOAL245_2': '2180.1',
#  'FACOAL246_1': '2180.1',
#  'FACOAL260': '2180.1',
#  'FACOAL40im': '116285.1',
#  'FACOAL80i': '2181.1 or 2181.2',
#  'FADDP': '5167.1 or 5169.1',
#  'FAEL183': '6785.1 or 79071.1 or 60481.1 or 54898.1',
#  'FAEL184': '6785.1 or 79071.1 or 60481.1 or 54898.1',
#  'FAEL204': '6785.1 or 79071.1 or 60481.1 or 54898.1',
#  'FAEL205': '6785.1 or 79071.1 or 60481.1 or 54898.1',
#  'FAH1': '1579.1',
#  'FAH2': '1579.1',
#  'FAH3': '1579.1',
#  'FALDH': '128.1',
#  'FAOXC11': '34.1',
#  'FAOXC140': '35.1 or 34.1',
#  'FAOXC150m': '35.1 or 34.1',
#  'FAOXC160': '34.1 or 35.1',
#  'FAOXC16080m': '35.1 or 34.1',
#  'FAOXC16080x': '(51.1 and 3295.1 and 30.1) or (51.1 and 30.1 and 1962.1) or (30.1 and 51.2 and 1962.1) or (3295.1 and 30.1 and 51.2)',
#  'FAOXC161802m': '34.1 or 35.1',
#  'FAOXC16180m': '35.1 or 34.1',
#  'FAOXC170m': '34.1',
#  'FAOXC180': '34.1 or 34.1 or 35.1 or 35.1',
#  'FAOXC180x': '(51.1 and 3295.1 and 30.1) or (51.1 and 30.1 and 1962.1) or (30.1 and 51.2 and 1962.1) or (3295.1 and 30.1 and 51.2)',
#  'FAOXC1811601m': '35.1 or 34.1',
#  'FAOXC1811602m': '35.1 or 34.1',
#  'FAOXC1811603m': '34.1 or 35.1',
#  'FAOXC182806m': '34.1 or 35.1',
#  'FAOXC18280m': '34.1 or 35.1',
#  'FAOXC183803m': '34.1 or 35.1',
#  'FAOXC183806m': '34.1 or 35.1',
#  'FAOXC183806x': '(3295.1 and 30.1 and 51.2) or (30.1 and 51.2 and 1962.1) or (51.1 and 3295.1 and 30.1) or (51.1 and 30.1 and 1962.1)',
#  'FAOXC18480m': '34.1 or 35.1',
#  'FAOXC18480x': '(51.1 and 3295.1 and 30.1) or (30.1 and 51.2 and 1962.1) or (51.1 and 30.1 and 1962.1) or (3295.1 and 30.1 and 51.2)',
#  'FAOXC200180m': '35.1 or 34.1',
#  'FAOXC200180x': '(3295.1 and 30.1 and 51.2) or (51.1 and 30.1 and 1962.1) or (51.1 and 3295.1 and 30.1) or (30.1 and 51.2 and 1962.1)',
#  'FAOXC2031836m': '35.1 or 34.1',
#  'FAOXC204': '35.1 or 35.1 or 34.1 or 34.1',
#  'FAOXC204184m': '35.1 or 34.1',
#  'FAOXC2051843m': '34.1 or 35.1',
#  'FAOXC2051843x': '(30.1 and 51.2 and 1962.1) or (51.1 and 3295.1 and 30.1) or (51.1 and 30.1 and 1962.1) or (3295.1 and 30.1 and 51.2)',
#  'FAOXC2242046m': '34.1 or 35.1',
#  'FAOXC2242046x': '(3295.1 and 30.1 and 51.2) or (51.1 and 30.1 and 1962.1) or (30.1 and 51.2 and 1962.1) or (51.1 and 3295.1 and 30.1)',
#  'FAOXC2251836m': '34.1 or 35.1',
#  'FAOXC2251836x': '(3295.1 and 30.1 and 51.2) or (51.1 and 30.1 and 1962.1) or (51.1 and 3295.1 and 30.1) or (30.1 and 51.2 and 1962.1)',
#  'FAOXC2252053m': '35.1 or 34.1',
#  'FAOXC2252053x': '(51.1 and 3295.1 and 30.1) or (30.1 and 51.2 and 1962.1) or (51.1 and 30.1 and 1962.1) or (3295.1 and 30.1 and 51.2)',
#  'FAOXC226': '35.1 or 34.1',
#  'FAOXC226205m': '35.1 or 34.1',
#  'FAOXC226205x': '(3295.1 and 30.1 and 51.2) or (51.1 and 3295.1 and 30.1) or (30.1 and 51.2 and 1962.1) or (51.1 and 30.1 and 1962.1)',
#  'FAOXC240200x': '(51.1 and 3295.1 and 30.1) or (30.1 and 51.2 and 1962.1) or (51.1 and 30.1 and 1962.1) or (3295.1 and 30.1 and 51.2)',
#  'FAOXC241181x': '(3295.1 and 30.1 and 51.2) or (51.1 and 30.1 and 1962.1) or (51.1 and 3295.1 and 30.1) or (30.1 and 51.2 and 1962.1)',
#  'FAOXC2442246x': '(51.1 and 3295.1 and 30.1) or (51.1 and 30.1 and 1962.1) or (30.1 and 51.2 and 1962.1) or (3295.1 and 30.1 and 51.2)',
#  'FAOXC2452253x': '(3295.1 and 30.1 and 51.2) or (30.1 and 51.2 and 1962.1) or (51.1 and 30.1 and 1962.1) or (51.1 and 3295.1 and 30.1)',
#  'FAOXC2452256x': '(3295.1 and 30.1 and 51.2) or (51.1 and 3295.1 and 30.1) or (30.1 and 51.2 and 1962.1) or (51.1 and 30.1 and 1962.1)',
#  'FAOXC246226x': '(3295.1 and 30.1 and 51.2) or (51.1 and 3295.1 and 30.1) or (30.1 and 51.2 and 1962.1) or (51.1 and 30.1 and 1962.1)',
#  'FAOXC260240x': '(3295.1 and 30.1 and 51.2) or (51.1 and 30.1 and 1962.1) or (51.1 and 3295.1 and 30.1) or (30.1 and 51.2 and 1962.1)',
#  'FAOXC80': '35.1 or 34.1',
#  'FAS100COA': '2194.1 or ((2194.1 and 79071.1) and 60481.1 and 54898.1)',
#  'FAS120COA': '2194.1 or ((2194.1 and 79071.1) and 60481.1 and 54898.1)',
#  'FAS140COA': '2194.1 or ((2194.1 and 79071.1) and 60481.1 and 54898.1)',
#  'FAS160COA': '2194.1 or ((2194.1 and 79071.1) and 60481.1 and 54898.1)',
#  'FAS180COA': '2194.1 or ((2194.1 and 79071.1) and 60481.1 and 54898.1)',
#  'FAS80COA_L': '2194.1',
#  'FATP1t': '376497.2 or 10999.1 or 376497.1 or 11000.1',
#  'FATP2t': '376497.1 or 376497.2',
#  'FATP3t': '376497.1 or 376497.2',
#  'FATP4t': '10998.1',
#  'FATP5t': '10998.1',
#  'FATP6t': '10998.1 or 11001.1',
#  'FATP7t': '10998.1 or 11001.1',
#  'FATP8t': '10998.1 or 11001.1',
#  'FATP9t': '10998.1 or 11001.1',
#  'FBA4': '226.2 or 229.1 or 226.3 or 230.1 or 226.1',
#  'FBA5': '229.1',
#  'FBP26': '2203.1 or 5210.1 or 5207.1 or 5209.1 or 5208.1 or 8789.1',
#  'FCLTm': '2235.1 or 2235.2',
#  'FDH': '10840.1',
#  'FE3R2e': '79901.1',
#  'FK': '197258.1',
#  'FKYNH': '125061.1',
#  'FOLR2': '1719.1',
#  'FOLt2': '6573.1 or 6573.2',
#  'FPGS2': '2356.1',
#  'FPGS2m': '2356.1',
#  'FPGS3': '2356.1',
#  'FPGS3m': '2356.1',
#  'FPGS4': '2356.1',
#  'FPGS4m': '2356.1',
#  'FPGS5': '2356.1',
#  'FPGS5m': '2356.1',
#  'FPGS6': '2356.1',
#  'FPGS6m': '2356.1',
#  'FPGS7m': '2356.1',
#  'FPGS8': '2356.1',
#  'FPGS8m': '2356.1',
#  'FPGS9': '2356.1',
#  'FPGS9m': '2356.1',
#  'FPGSm': '2356.1',
#  'FRUt1r': '29988.1 or 6514.1 or 155184.1 or 6518.1 or 66035.1',
#  'FTHFDH': '10840.1 or 160428.1',
#  'FTHFLm': '25902.1 or 4522.1',
#  'FUCASE2e': '2519.1',
#  'FUCASE2ly': '2517.1',
#  'FUCASEe': '2519.1',
#  'FUCASEly': '2517.1',
#  'FUMAC': '2184.1',
#  'FUMm': '2271.1',
#  'FUMSO3tm': '1468.1',
#  'FUMSO4tm': '1468.1',
#  'FUMtm': '1468.1',
#  'FUMTSULtm': '1468.1',
#  'FUT11g': '2523.1',
#  'FUT12g': '2523.1',
#  'FUT14g': '2523.1',
#  'FUT15g': '2523.1',
#  'FUT16g': '2523.1',
#  'FUT17g': '2523.1',
#  'FUT18g': '2523.1',
#  'FUT31g': '2525.1',
#  'FUT32g': '2525.1',
#  'FUT33g': '2525.1',
#  'FUT34g': '2525.1',
#  'FUT35g': '2525.1',
#  'FUT910g': '10690.1',
#  'FUT911g': '10690.1',
#  'FUT91g': '10690.1',
#  'FUT92g': '10690.1',
#  'FUT93g': '10690.1',
#  'FUT94g': '10690.1',
#  'FUT95g': '10690.1',
#  'FUT96g': '10690.1',
#  'FUT97g': '10690.1',
#  'FUT98g': '10690.1',
#  'FUT99g': '10690.1',
#  'G13MT_L': '85365.1 or 85365.2',
#  'G13MT_U': '85365.1 or 85365.2',
#  'G14T10g': '9334.1 or 2683.1 or 8703.1 or 8704.2 or 8704.1',
#  'G14T11g': '8703.1 or 8704.2 or 8704.1 or 2683.1 or 9334.1',
#  'G14T12g': '8703.1 or 2683.1 or 8704.2 or 8704.1 or 9334.1',
#  'G14T13g': '8703.1 or 2683.1 or 8704.2 or 8704.1 or 9334.1',
#  'G14T14g': '8703.1 or 8704.2 or 8704.1 or 2683.1 or 9334.1',
#  'G14T15g': '8703.1 or 2683.1 or 8704.2 or 8704.1 or 9334.1',
#  'G14T16g': '8703.1 or 2683.1 or 8704.2 or 8704.1 or 9334.1',
#  'G14T17g': '8703.1 or 8704.2 or 8704.1 or 2683.1 or 9334.1',
#  'G14T18g': '8703.1 or 8704.2 or 8704.1 or 2683.1 or 9334.1',
#  'G14T19g': '9334.1 or 8704.1 or 8703.1 or 8704.2 or 2683.1',
#  'G14T20g': '8703.1 or 2683.1 or 8704.2 or 8704.1 or 9334.1',
#  'G14T21g': '8703.1 or 2683.1 or 8704.2 or 8704.1 or 9334.1',
#  'G14T2g': '8703.1 or 2683.1 or 8704.2 or 8704.1 or 9334.1',
#  'G14T3g': '8703.1 or 2683.1 or 8704.2 or 8704.1 or 9334.1',
#  'G14T4g': '8703.1 or 2683.1 or 8704.2 or 8704.1 or 9334.1',
#  'G14T5g': '9334.1 or 2683.1 or 8704.2 or 8704.1 or 8703.1',
#  'G14T6g': '8703.1 or 2683.1 or 8704.2 or 8704.1 or 9334.1',
#  'G14T7g': '8704.1 or 8703.1 or 2683.1 or 9334.1 or 8704.2',
#  'G14T8g': '8703.1 or 2683.1 or 8704.2 or 8704.1 or 9334.1',
#  'G14T9g': '8703.1 or 2683.1 or 8704.2 or 8704.1 or 9334.1',
#  'G14Tg': '9334.1 or 2683.1 or 8704.1 or 8703.1 or 8704.2',
#  'G3PD2m': '2820.1',
#  'G5SDym': '5832.1',
#  'G6PDH1rer': '9563.1',
#  'G6PDH2rer': '9563.1 or 2539.1',
#  'G6PPer': '57818.1 or 2538.1 or 92579.1',
#  'G6Pter': '2542.1',
#  'GABAVESSEC': '140679.1',
#  'GACMTRc': '2593.1 or 2593.2',
#  'GAL3ST11': '9514.1',
#  'GAL3ST12': '9514.1',
#  'GALASE10ly': '(5476.1 and 2720.1 and 2588.1 and 4758.1) or (5476.1 and 2720.1)',
#  'GALASE11ly': '(5476.1 and 2720.1 and 2588.1 and 4758.1) or (5476.1 and 2720.1)',
#  'GALASE12ly': '(5476.1 and 2720.1 and 2588.1 and 4758.1) or (5476.1 and 2720.1)',
#  'GALASE13ly': '(5476.1 and 2720.1 and 2588.1 and 4758.1) or (5476.1 and 2720.1)',
#  'GALASE14ly': '(5476.1 and 2720.1 and 2588.1 and 4758.1) or (5476.1 and 2720.1)',
#  'GALASE15ly': '(5476.1 and 2720.1 and 2588.1 and 4758.1) or (5476.1 and 2720.1)',
#  'GALASE16ly': '(5476.1 and 2720.1 and 2588.1 and 4758.1) or (5476.1 and 2720.1)',
#  'GALASE17ly': '(5476.1 and 2720.1 and 2588.1 and 4758.1) or (5476.1 and 2720.1)',
#  'GALASE18ly': '(5476.1 and 2720.1 and 2588.1 and 4758.1) or (5476.1 and 2720.1)',
#  'GALASE19ly': '(5476.1 and 2720.1 and 2588.1 and 4758.1) or (5476.1 and 2720.1)',
#  'GALASE1ly': '(5476.1 and 2720.1 and 2588.1 and 4758.1) or (5476.1 and 2720.1)',
#  'GALASE20ly': '(5476.1 and 2720.1 and 2588.1 and 4758.1) or (5476.1 and 2720.1)',
#  'GALASE3ly': '(5476.1 and 2720.1 and 2588.1 and 4758.1) or (5476.1 and 2720.1)',
#  'GALASE4ly': '(5476.1 and 2720.1 and 2588.1 and 4758.1) or (5476.1 and 2720.1)',
#  'GALASE5ly': '(5476.1 and 2720.1 and 2588.1 and 4758.1) or (5476.1 and 2720.1)',
#  'GALASE6ly': '(5476.1 and 2720.1 and 2588.1 and 4758.1) or (5476.1 and 2720.1)',
#  'GALASE7ly': '(5476.1 and 2720.1 and 2588.1 and 4758.1) or (5476.1 and 2720.1)',
#  'GALASE8ly': '(5476.1 and 2720.1 and 2588.1 and 4758.1) or (5476.1 and 2720.1)',
#  'GALASE9ly': '(5476.1 and 2720.1 and 2588.1 and 4758.1) or (5476.1 and 2720.1)',
#  'GALC': '2581.1',
#  'GALGT1': '2583.1',
#  'GALGT2': '2583.1',
#  'GALGT3': '2583.1',
#  'GALGT4': '2583.1',
#  'GALNACT1g': '55790.1 or 55454.1',
#  'GALNACT2g': '(79586.1 and 22856.1) or 337876.1 or 55454.1 or 55790.1',
#  'GALNACT3g': '(79586.1 and 22856.1) or 337876.1 or 55454.1 or 55790.1',
#  'GALNACT4g': '(79586.1 and 22856.1) or 337876.1 or 55454.1 or 55790.1',
#  'GALNACT5g': '(79586.1 and 22856.1) or 337876.1 or 55454.1 or 55790.1',
#  'GALNTg': '26290.1 or 79695.1 or 2589.1 or 50614.1 or 8693.1 or 55568.2 or 114805.1 or 11226.1 or 117248.1 or 11227.1 or 55568.1 or 2590.1 or 51809.1 or 26290.1 or 79623.1 or 63917.1 or 2591.1',
#  'GALOR': '231.1 or 10327.2 or 10327.1',
#  'GALt1r': '29988.1 or 6513.1 or 6515.1 or 6514.1 or 81031.1',
#  'GALT2g': '126792.1',
#  'GALTg': '11285.1',
#  'GAMt1r': '6513.1 or 6517.1 or 6514.1',
#  'GAMYe': '8972.1',
#  'GAO1': '9197.1',
#  'GAO1g': '9197.1',
#  'GAO2': '9197.1',
#  'GAO2g': '9197.1',
#  'GARFT': '2618.1 or 2618.2',
#  'GASNASE2ly': '175.1',
#  'GASNASE3ly': '175.1',
#  'GASNASEly': '175.1',
#  'GBA': '2629.2 or 2629.3 or 2629.4 or 2629.5 or 2629.1',
#  'GBAl': '2629.4 or 2629.1 or 2629.3 or 2629.2 or 2629.5',
#  'GBGT1': '26301.1',
#  'GCALDDm': '4329.1 or 7915.1 or 8659.1 or 5832.1 or 217.1 or 7915.2 or 219.1 or 8659.2',
#  'GCC2am': '275.1 and 1738.1 and 2731.1 and 2653.1',
#  'GCC2bim': '275.1 and 1738.1 and 2731.1 and 2653.1',
#  'GCC2cm': '275.1 and 1738.1 and 2731.1 and 2653.1',
#  'GCCam': '275.1 and 1738.1 and 2731.1 and 2653.1',
#  'GCCbim': '275.1 and 1738.1 and 2731.1 and 2653.1',
#  'GCCcm': '275.1 and 1738.1 and 2731.1 and 2653.1',
#  'GCHOLAt': '6579.1 or 28234.1 or 10599.1',
#  'GCHOLAt2': '6554.1 or 6555.1',
#  'GCNTg': '2651.1',
#  'GDPFUCtg': '55343.1',
#  'GFUCS': '7264.1',
#  'GGH_10FTHF5GLUe': '8836.1',
#  'GGH_10FTHF5GLUl': '8836.1',
#  'GGH_10FTHF6GLUe': '8836.1',
#  'GGH_10FTHF6GLUl': '8836.1',
#  'GGH_10FTHF7GLUe': '8836.1',
#  'GGH_10FTHF7GLUl': '8836.1',
#  'GGH_5DHFe': '8836.1',
#  'GGH_5DHFl': '8836.1',
#  'GGH_5THFe': '8836.1',
#  'GGH_5THFl': '8836.1',
#  'GGH_6DHFe': '8836.1',
#  'GGH_6DHFl': '8836.1',
#  'GGH_6THFe': '8836.1',
#  'GGH_6THFl': '8836.1',
#  'GGH_7DHFe': '8836.1',
#  'GGH_7DHFl': '8836.1',
#  'GGH_7THFe': '8836.1',
#  'GGH_7THFl': '8836.1',
#  'GGLUCT': '79017.1',
#  'GGNG': '(8908.1 and 2998.1) or (2998.1 and 2992.1) or (2997.1 and 2992.1) or (8908.1 and 2997.1)',
#  'GGT5r': '2687.1',
#  'GHMT2rm': '6472.1 or 6470.1',
#  'GHMT3': '6470.1 or 6470.2',
#  'GHMT3m': '6472.1',
#  'GK1m': '2987.1',
#  'GLACO': '223.1 or 220.1 or 224.1 or 8854.2 or 218.1 or 8854.1 or 216.1 or 221.1 or 8854.3 or 222.1',
#  'GLACOm': '8659.2 or 217.1 or 8659.1 or 219.1',
#  'GLAl': '2717.1',
#  'GLB1': '(5476.1 and 2720.1 and 2588.1 and 4758.1) or (5476.1 and 2720.1)',
#  'GLBRAN': '2632.1',
#  'GLCAASE1ly': '2990.1',
#  'GLCAASE4ly': '2990.1',
#  'GLCAASE5ly': '2990.1',
#  'GLCAASE6ly': '2990.1',
#  'GLCAASE7ly': '2990.1',
#  'GLCAASE8ly': '2990.1 or 8372.1',
#  'GLCAASE9ly': '2990.1',
#  'GLCAE2g': '26035.1',
#  'GLCAT2g': '54480.1 or (79586.1 and 22856.1) or 337876.1',
#  'GLCAT3g': '54480.1 or (79586.1 and 22856.1) or 337876.1',
#  'GLCAT4g': '54480.1 or (79586.1 and 22856.1) or 337876.1',
#  'GLCAT5g': '54480.1 or (79586.1 and 22856.1) or 337876.1',
#  'GLCAT6g': '(2131.1 and 2132.1) or (2131.1 and 2132.2)',
#  'GLCAT7g': '(2131.1 and 2132.1) or (2131.1 and 2132.2)',
#  'GLCAT8g': '(2131.1 and 2132.1) or (2131.1 and 2132.2)',
#  'GLCAT9g': '(2131.1 and 2132.1) or (2131.1 and 2132.2)',
#  'GLCATg': '27087.2 or 135152.1 or 27087.1 or 26229.1',
#  'GLCNACASE1ly': '4669.1',
#  'GLCNACASE2ly': '4669.1',
#  'GLCNACASE3ly': '4669.1',
#  'GLCNACASE4ly': '4669.1',
#  'GLCNACASE5ly': '4669.1',
#  'GLCNACDASg': '64579.1 or 3340.1 or 9348.1 or 8509.1',
#  'GLCNACPT_L': '1798.1 or 1798.2',
#  ...}

# %%
mets = pd.read_csv('../../data/NAD_cell_lines/merged_metabolites_measurement.csv')
sc = util.reshape(model.gs[~model.gs.index.str.contains('HC02111')], include=None)
sc = sc.query('metabolites in @mets.fullName')
sc = sc.drop(['metabolites', 'compartment'], axis=1)

# %%
rna = pd.read_csv('../data/NAD_cell_lines/gene_fpkm.xls.csv', index_col=0)
rna1 = util.map_gene(df=rna, g_mapping=model.genes, mapping_column='ensembl_gene')
rna_hek = rna1[rna1.columns[rna1.columns.str.contains('wtHEK293|HEK25a51|HEK25A51')]]
rna_hek = rna_hek.replace(0.0, np.nan).dropna(axis=0)

wt = rna_hek.columns[rna_hek.columns.str.contains('wtHEK293')]
ko = rna_hek.columns[rna_hek.columns.str.contains('HEK25a51ko')]
oe = rna_hek.columns[rna_hek.columns.str.contains('HEK25A51oe')]

# %%
rna[oe].mean(axis=1).div(rna[wt].mean(axis=1)).replace(np.inf, np.nan).dropna().max()

# %%
df = model.get_subsystem_from_gene(model.genes.gene_number.astype('str'))

# %%
df

# %%
list_of_mapped_compounds = ['L-Methionine', 'L-Tryptophan']
pathways = {}
for met in model.metabolites[model.metabolites.fullName.isin(list_of_mapped_compounds)]['abbreviation']:
    pathways[met] = list(
                set(model.reactions[model.reactions.formula.str.contains(met)]['subsystem']))
    
subsytems = []
for v in pathways.values():
    subsytems = subsytems + v

m_paths = {}
for p in list(set(subsytems)):
    m_paths[p] = [k for k, v in pathways.items() if p in v]

# %%
_m = model.get_reactions_from_metabolite('Oxoglutaric acid').set_index('abbreviation')
# _g = df[['gene_number', 'abbreviation', 'uniprot_gname']].set_index('abbreviation')

# %%
_m.subsystem.unique()

# %%
len(_g.merge(_m, on='abbreviation').index.intersection(_m.index))

# %%
_g.merge(_m, on='abbreviation')

# %%
len(set(_m.index))

# %%
model.reactions.query('abbreviation == "ALASm"')

# %%
model.reactions.query('subsystem == "Citric acid cycle"')

# %%
rxn_nad = model.get_reactions_from_metabolite('NAD')
rxn_nad.query('subsystem == "NAD metabolism"')

# %%
model.reactions.query('formula.str.contains("nad") and description.str.contains("Transport")')

# %%
model.reactions.query('abbreviation.str.contains("NADt")')

# %%
gpr = model.gpr.copy()
gpr['NADtm'] = '6398.1'
# genes = model.genes.copy()
# genes.gene_number = genes.gene_number.astype('str')
# genes[genes.gene_number.str.contains('6398')]

# %%
model.model.reactions.get_by_id('NADtm')#.gene_reaction_rule = '6398.1'

# %%
cmodel = model.add_gene_to_rxn(cobra_model=model.model, rxn_id='NADtm', gene_number='6398.1')

# %%
cmodel.reactions.get_by_id('NADtm')

# %%
import pyreporter as pr

# %%
# pd.Series({i:1.0 for i in model.genes.gene_number})
gr_rule = model.model.reactions.get_by_id('nd')#.gene_reaction_rule# = '6398.1'
# assert len(gr_rule.genes) == 0, 'Reaction is not enzyme catalysed.'
gr_rule

# %%
rxn.gene_reaction_rule
# len(model.model.reactions.get_by_id('13DAMPPOX').gene_reaction_rule)

# %%
pr.workflows.workflow_Fang2012(cobra_model=cmodel, mapped_genes_baseline=pd.Series({i:1.0 for i in model.genes.gene_number}),
                            #    mapped_genes_comparison=pd.Series({'8639.1': 1.0}), 
                               mapped_genes_comparison=pd.Series({'6398.1': 1e-6}), 
                               gene_fill=1.0)

# %%
df = pd.DataFrame(_)

# %%
df.query('index.str.contains("nad")')

# %%
def get_top_rxns(sc, metabolite, n=10):
    _cc = sc[sc.index == metabolite].T.abs().sort_values(by=metabolite)
    tail = _cc.tail(n)
    rxns = tail.index.tolist()
    # rxns.sort()
    return rxns

# %%
prot = pd.read_csv('../data/NAD_cell_lines/mapped_proteome_DDA_five_of_five.csv', sep='\t', index_col=0)
prot.index = prot.index.astype('str')

# %%
pko = prot.filter(like="ko").mean(axis=1).div(prot.filter(like="wt").mean(axis=1))
rko = rna1[ko].mean(axis=1).div(rna1[wt].mean(axis=1))

# %%
prko = pd.concat([pko, rko], axis=1).dropna()
prko.columns = ['proteomics', 'transcriptomics']

# %%
_prko = prko.query('(proteomics > 1.0 and transcriptomics > 1.0) or (proteomics < 1.0 and transcriptomics < 1.0)')
# sns.scatterplot(data=np.log2(_prko), x='proteomics', y='transcriptomics')

# %%
gene2rxn = model.get_subsystem_from_gene(_prko.index)

# %%
gene2rxn

# %%
met2rxn = pd.DataFrame()
for met in mets.fullName.unique():
    _rxns = model.get_reactions_from_metabolite(met)
    _rxns['metabolite'] = met
    met2rxn = pd.concat((met2rxn, _rxns), axis=0)

# %%
met2rxn.query('abbreviation in @gene2rxn.abbreviation').metabolite.unique()

# %%
sns.scatterplot(data=prko, x='proteomics', y='transcriptomics', alpha=0.5)

# %%
rxns = [get_top_rxns(sc, i, n=20) for i in sc.index]
top_rxns = pd.DataFrame(rxns, index=sc.index).T
top_rxns

# %%
rna.columns

# %%
met_wt = rna1[rna1.index.isin(get_top_rxns(sc, 'L-Methionine[c]', n=50))][wt].mean(axis=1)
met_ko = rna1[rna1.index.isin(get_top_rxns(sc, 'L-Methionine[c]', n=50))][ko].mean(axis=1)
met_oe = rna1[rna1.index.isin(get_top_rxns(sc, 'L-Methionine[c]', n=50))][oe].mean(axis=1)

# %%
_met = sc[(sc.index == 'L-Methionine[c]')].T
_met = _met[_met['L-Methionine[c]'] != 0.0]
_met = _met[_met.index.isin(rna1.index)]

# %%
_df = pd.concat((rna1[rna1.index.isin(_met.index)][wt].mean(axis=1),
                 rna1[rna1.index.isin(_met.index)][ko].mean(axis=1),
                 rna1[rna1.index.isin(_met.index)][oe].mean(axis=1)), axis=1)
_df.columns = ['wt', 'ko', 'oe']

# %%
sns.kdeplot(data=np.log2(_df), fill=True, alpha=0.2)

# %%
sns.scatterplot(data=_df, x='wt', y='ko', alpha=0.5)

# %%
_df1 = _df['ko'].div(_df['wt']).replace([np.inf, np.nan]).dropna()
_df1[(_df1 != 1.0) & (_df1 > 0.0)].min()

# %%
model.model.reactions.get_by_id('10FTHF5GLUtm')

# %%
model.get_reactions(_df1[:1].index)

# %%
list_of_gene_number = rna_hek[:10].index.to_list()

# %%
g_paths = []
for p in list_of_gene_number:
    g_paths = g_paths + [(p, k) for k, v in model.gpr.items() if p in v]
g_paths = pd.DataFrame(g_paths, columns=['gene_number', 'reaction_id'])

for rxn in g_paths.reaction_id:
    g_paths.loc[g_paths['reaction_id'] == rxn, 'subsystem'] = model.reactions[model.reactions.abbreviation == rxn].subsystem.iloc[0]

g_paths.gene_number  = g_paths.gene_number.astype('float')   
g_paths.merge(model.genes[['gene_number', 'symbol', 'uniprot_gname', 'description', 'ensembl_gene', 'ensembl_trans']], on='gene_number')

# %%
len(model.reactions[model.reactions.abbreviation.isin(g_paths.reaction_id)].subsystem)

# %%
# p = list_of_gene_number[0]
# [(p, k) for k, v in model.gpr.items() if p in v]
_df = pd.DataFrame(g_paths)

# %%
for rxn in 
_df.loc[_df[1] == "HMR_0597", 'subsystem'] = model.reactions[model.reactions.abbreviation == "HMR_0597"].subsystem.iloc[0]

# %%
_df

# %%
# model.reactions.query('abbreviation in @m_paths')
model.reactions[model.reactions.abbreviation == "HMR_0597"].subsystem.iloc[0]
